# %%
import sys
import copy
import time

import numpy as np
import torch
import matplotlib.pyplot as plt

sys.path.insert(0, '..')
from graph_deep_decoder import datasets as ds
from graph_deep_decoder import utils
from graph_deep_decoder.architecture import GraphDecoder
from graph_deep_decoder.model import Model

SEED = 0
torch.manual_seed(SEED)
np.random.seed(SEED)

# Graph parameters
Gs = {}
Gs['type'] = ds.SBM
Gs['N'] = 64
Gs['k'] = 4
Gs['type_z'] = ds.CONT
Gs['p'] = 0.7
Gs['q'] = 0.015

# Signal parameters
K = 3
params = 4
n_signals = 100
n_p = 0.1

# Model parameters
fts = 150
epochs = 1000
lr = 0.001

# Create graph
G = ds.create_graph(Gs, SEED)
A = G.W.todense()
plt.figure()
plt.imshow(A)

# Create filter H and decoder
hs = np.random.rand(K)
hs /= np.sum(hs)
print('Filter coefs:', hs)
x_dw = ds.DiffusedWhiteGS(G, ds.NonLin.NONE, K, coefs=hs)
H = x_dw.H

# Prepare experiments
scales = [1e-15, .001, .01, .1, .5, 1, 10]
#exps = [{'scale': 1, 'fixed': True}]
# Out:
# Filter coefs: [0.29399155 0.38311672 0.32289173]

# %%
# Fit models
err = np.zeros((len(scales), n_signals, epochs, G.N))
err_wrt_n = np.zeros((len(scales), n_signals, epochs, G.N))
start_time = time.time()
for i in range(n_signals):
    for j, scale in enumerate(scales):
        dec = GraphDecoder(fts, H, scale_std=scale)
        JJ = dec.analytical_squared_jacobian()
        Lambda, V = utils.ordered_eig(JJ)
        x = ds.bandlimited_signal(Lambda, V, params)
        x_n = ds.GraphSignal.add_noise(x, n_p)
        model = Model(dec, epochs=epochs, learning_rate=lr)
        err_wrt_n[j, i, :, :], err[j, i, :, :], _ = model.fit(x_n, x, reduce_err=False)

    print('Signal', i, 'done')

print('--- {} minutes ---'.format((time.time()-start_time)/60))
# Out:
# Signal 0 done
# Signal 1 done
# Signal 2 done
# Signal 3 done
# Signal 4 done
# Signal 5 done
# Signal 6 done
# Signal 7 done
# Signal 8 done
# Signal 9 done
# Signal 10 done
# Signal 11 done
# Signal 12 done
# Signal 13 done
# Signal 14 done
# Signal 15 done
# Signal 16 done
# Signal 17 done
# Signal 18 done
# Signal 19 done
# Signal 20 done
# Signal 21 done
# Signal 22 done
# Signal 23 done
# Signal 24 done
# Signal 25 done
# Signal 26 done
# Signal 27 done
# Signal 28 done
# Signal 29 done
# Signal 30 done
# Signal 31 done
# Signal 32 done
# Signal 33 done
# Signal 34 done
# Signal 35 done
# Signal 36 done
# Signal 37 done
# Signal 38 done
# Signal 39 done
# Signal 40 done
# Signal 41 done
# Signal 42 done
# Signal 43 done
# Signal 44 done
# Signal 45 done
# Signal 46 done
# Signal 47 done
# Signal 48 done
# Signal 49 done
# Signal 50 done
# Signal 51 done
# Signal 52 done
# Signal 53 done
# Signal 54 done
# Signal 55 done
# Signal 56 done
# Signal 57 done
# Signal 58 done
# Signal 59 done
# Signal 60 done
# Signal 61 done
# Signal 62 done
# Signal 63 done
# Signal 64 done
# Signal 65 done
# Signal 66 done
# Signal 67 done
# Signal 68 done
# Signal 69 done
# Signal 70 done
# Signal 71 done
# Signal 72 done
# Signal 73 done
# Signal 74 done
# Signal 75 done
# Signal 76 done
# Signal 77 done
# Signal 78 done
# Signal 79 done
# Signal 80 done
# Signal 81 done
# Signal 82 done
# Signal 83 done
# Signal 84 done
# Signal 85 done
# Signal 86 done
# Signal 87 done
# Signal 88 done
# Signal 89 done
# Signal 90 done
# Signal 91 done
# Signal 92 done
# Signal 93 done
# Signal 94 done
# Signal 95 done
# Signal 96 done
# Signal 97 done
# Signal 98 done
# Signal 99 done
# --- 12.850645176569621 minutes ---

# %%
# Plots Median Error
med_mse = np.median(np.sum(err, axis=3), axis=1)
plt.figure()
plt.semilogy(med_mse.T)
plt.grid(True, which='both')
plt.legend(scales)
plt.title('Median MSE wrt original')
plt.tight_layout()

# Plot Errors on JJ eig
ind = np.array([0, 1, 2, 29, -2, -1])
for i, scale in enumerate(scales):
    dec = GraphDecoder(fts, H, scale_std=scale)
    JJ = dec.analytical_squared_jacobian()
    _, V = utils.ordered_eig(JJ)
    V_ind = V[:, ind]
    
    proj_err = np.median(err_wrt_n[i, :, :, :].dot(V_ind), axis=0)
    plt.figure()
    plt.semilogy(np.abs(proj_err))
    plt.legend(ind)
    plt.grid(True, which='both')
    plt.title('Median Proj Err wrt noise - scale {}'.format(scale))
    plt.tight_layout()

# %%
plt.show()
